# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Exercise 1

# %%
! ls data
# Out:
# cars.csv                      organdonation.csv
# kaggle-uber-other-federal.csv

# %%
df_cars = pd.read_csv("data/cars.csv")

# %%
df_cars.head(5)
# Out:
#     MPG  CYL    ENG   WGT
# 0  18.0    8  307.0  3504
# 1  15.0    8  350.0  3693
# 2  18.0    8  318.0  3436
# 3  16.0    8  304.0  3433
# 4  17.0    8  302.0  3449

# %% [markdown]
# ## Exercise 2

# %%
df_cars2 = pd.read_csv("data/cars.csv")

# %%
list(df_cars2.columns)
# Out:
# ['MPG', 'CYL', 'ENG', 'WGT']

# %%
len(df_cars2)
# Out:
# 392

# %%
import matplotlib.pyplot as plt
# %config InlineBackend.figure_format = 'svg'

# %%
fig, ax = plt.subplots(figsize = (2,2))
ax.hist(df_cars2['ENG'])
ax.set_title("Engine Histogram")
# Out:
# Text(0.5, 1.0, 'Engine Histogram')

# %%
fig, ax = plt.subplots(figsize = (2,2))
ax.scatter(df_cars2['WGT'], df_cars2['MPG'])
ax.set_title("MPG vs WGT")
plt.xlabel("WGT")
plt.ylabel("MPG")
# Out:
# Text(0, 0.5, 'MPG')

# %% [markdown]
# ## Exercise 3
